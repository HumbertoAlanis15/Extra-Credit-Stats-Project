# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Cars Datasets 2025.csv', encoding='latin-1')
df
# Out:
#      Company Names         Cars Names                             Engines  \
# 0          FERRARI      SF90 STRADALE                                  V8
# 1      ROLLS ROYCE            PHANTOM                                 V12
# 2             Ford                KA+                         1.2L Petrol
# 3         MERCEDES            GT 63 S                                  V8
# 4             AUDI         AUDI R8 Gt                                 V10
# ...            ...                ...                                 ...
# 1213        Toyota       Crown Signia                      2.5L Hybrid I4
# 1214        Toyota  4Runner (6th Gen)  2.4L Turbo I4 (i-FORCE MAX Hybrid)
# 1215        Toyota      Corolla Cross              2.0L Gas / 2.0L Hybrid
# 1216        Toyota             C-HR+                   1.8L / 2.0L Hybrid
# 1217        Toyota     RAV4 (6th Gen)        2.5L Hybrid / Plug-in Hybrid
#
#         CC/Battery Capacity    HorsePower Total Speed  \
# ...

# %%
df_cars = df[df['Company Names'] == 'Chevrolet']
df_cars_prices = df_cars[['Company Names', 'Car Prices']]
df_2 = df_cars_prices.head()
df_2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 df_cars = df[df['Company Names'] == 'Chevrolet']
# ----> 2 df_cars_prices = df_cars[['Company Names', 'Car Prices']]
#       3 df_2 = df_cars_prices.head()
#       4 df_2
#
# File /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/lib/python3.13/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/lib/python3.13/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
# ...
